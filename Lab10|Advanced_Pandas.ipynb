# %% [markdown]
# # Lab|Advanced_Pandas

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Challenge 1 - Index Functions
# In this challenge, we will practice the advanced functions introduced in the lesson. However, before we start, we will load and evaluate our dataset.
#
# Load the dataset from Ironhack's database:
#
# db: admissions predict
# table: admissions predict

# %%
admission_df = pd.read_csv("Admission_Predict.csv")
admission_df.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        316          104                  3  3.0   3.5  8.00
# 2           3        322          110                  3  3.5   2.5  8.67
# 3           4        314          103                  2  2.0   3.0  8.21
# 4           5        330          115                  5  4.5   3.0  9.34
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.72
# 2         1              0.80
# 3         0              0.65
# 4         1              0.90

# %% [markdown]
# # Remove trailing spaces at the end of the column names if there are any.

# %%
admission_df.columns = admission_df.columns.str.rstrip()
admission_df
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0             1        337          118                  4  4.5  4.5  9.65
# 1             2        316          104                  3  3.0  3.5  8.00
# 2             3        322          110                  3  3.5  2.5  8.67
# 3             4        314          103                  2  2.0  3.0  8.21
# 4             5        330          115                  5  4.5  3.0  9.34
# ..          ...        ...          ...                ...  ...  ...   ...
# 380         381        324          110                  3  3.5  3.5  9.04
# 381         382        325          107                  3  3.0  3.5  9.11
# 382         383        330          116                  4  5.0  4.5  9.45
# 383         384        312          103                  3  3.5  4.0  8.78
# 384         385        333          117                  4  5.0  4.0  9.66
#
#      Research  Chance of Admit
# 0           1             0.92
# 1           1             0.72
# 2           1             0.80
# 3           0             0.65
# 4           1             0.90
# ..        ...              ...
# 380         1             0.82
# 381         1             0.84
# 382         1             0.91
# 383         0             0.67
# 384         1             0.95
#
# [385 rows x 9 columns]

# %%
#.str.strip() is used to remove leading and trailing spaces from each column name.
#. In the context of column names in a Pandas DataFrame, trailing spaces would be spaces that are present at the end of a column name string.

# %% [markdown]
# # Let's evaluate the dataset by looking at the head function.

# %%
admission_df.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0           1        337          118                  4  4.5  4.5  9.65
# 1           2        316          104                  3  3.0  3.5  8.00
# 2           3        322          110                  3  3.5  2.5  8.67
# 3           4        314          103                  2  2.0  3.0  8.21
# 4           5        330          115                  5  4.5  3.0  9.34
#
#    Research  Chance of Admit
# 0         1             0.92
# 1         1             0.72
# 2         1             0.80
# 3         0             0.65
# 4         1             0.90

# %% [markdown]
# # Before beginning to work with this dataset and evaluating graduate admissions data, we will verify that there is no missing data in the dataset.
# #Do this in the cell below.

# %%
#Check for the missing data in dataframe
missing_data = admission_df.isna().sum()
missing_data
# Out:
# Serial No.           0
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64

# %%
# Display columns with missing data (if any)
#print("Columns with missing data:")
#print(missing_data[missing_data > 0])

# %% [markdown]
# # Interestingly, there is a column that uniquely identifies the applicants. This column is the serial number column.
# #Instead of having our own index, we should make this column our index. Do this in the cell below.
# #Keep the column in the dataframe in addition to making it an index.

# %%
admission_df.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0           1        337          118                  4  4.5  4.5  9.65
# 1           2        316          104                  3  3.0  3.5  8.00
# 2           3        322          110                  3  3.5  2.5  8.67
# 3           4        314          103                  2  2.0  3.0  8.21
# 4           5        330          115                  5  4.5  3.0  9.34
#
#    Research  Chance of Admit
# 0         1             0.92
# 1         1             0.72
# 2         1             0.80
# 3         0             0.65
# 4         1             0.90

# %%
# Set the "Serial No." column as the index
admission_df = admission_df.set_index('Serial No.')

# Now, the "Serial No." column serves as the index of the DataFrame and functions as both the index and 
#regular column in our dataframe.

# %%
admission_df.head()
# Out:
#             GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# Serial No.
# 1                 337          118                  4  4.5  4.5  9.65
# 2                 316          104                  3  3.0  3.5  8.00
# 3                 322          110                  3  3.5  2.5  8.67
# 4                 314          103                  2  2.0  3.0  8.21
# 5                 330          115                  5  4.5  3.0  9.34
#
#             Research  Chance of Admit
# Serial No.
# 1                  1             0.92
# 2                  1             0.72
# 3                  1             0.80
# 4                  0             0.65
# 5                  1             0.90

# %%
#Turns out that GRE Score and CGPA also uniquely identify the data. Show this in the cell below.

# %%
#I tried to do it with two methods:
# Method 1:
# Count the number of unique combinations of "GRE Score" and "CGPA"
unique_count = admission_df.groupby(['GRE Score', 'CGPA']).size()
unique_count
# Out:
# GRE Score  CGPA
# 290        7.46    1
#            7.56    1
# 293        7.80    1
# 294        7.36    1
#            7.64    1
#                   ..
# 340        9.60    1
#            9.66    1
#            9.74    1
#            9.91    1
#            9.92    1
# Length: 385, dtype: int64

# %%
   # Print the result
if unique_count.shape[0] == total_rows:
    print("The combination of 'GRE Score' and 'CGPA' uniquely identifies the data.")
else:
    print("There are duplicate combinations based on 'GRE Score' and 'CGPA'.")
# Out:
# The combination of 'GRE Score' and 'CGPA' uniquely identifies the data.

# %% [markdown]
# #
# we can also do it by .duplicated() method to check for  duplicate rows based on these two columns. If there are
# no duplicates, it confirms that this combination is unique.

# %%
# Method2:
# Check for duplicate rows based on 'GRE Score' and 'CGPA' columns
duplicates = admission_df[admission_df.duplicated(subset=['GRE Score', 'CGPA'])]


# Print the result
if duplicates.empty:
    print("The combination of 'GRE Score' and 'CGPA' uniquely identifies the data.")
else:
    print("There are duplicate rows based on 'GRE Score' and 'CGPA'.")
# Out:
# The combination of 'GRE Score' and 'CGPA' uniquely identifies the data.

# %%
duplicates
# Out:
# Empty DataFrame
# Columns: [GRE Score, TOEFL Score, University Rating, SOP, LOR, CGPA, Research, Chance of Admit]
# Index: []

# %% [markdown]
# # Replace the index with an index comprised of two columns - GRE Score and CGPA. Remove the columns from the dataset as well. Make sure to use inplace=True.
#
# #Now change the index back to a sequence starting at zero using the reset_index function. Make sure to use inplace=True.

# %%
copied_admission_df = admission_df.copy()

# %%
copied_admission_df.sample(3)
# Out:
#             GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# Serial No.
# 12                307          109                  3  4.0  3.0   8.0
# 277               313          109                  3  4.0  3.5   9.0
# 6                 321          109                  3  3.0  4.0   8.2
#
#             Research  Chance of Admit
# Serial No.
# 12                 1             0.62
# 277                0             0.79
# 6                  1             0.75

# %%
# Set a multi-index consisting of "GRE Score" and "CGPA"
copied_admission_df.set_index(['GRE Score', 'CGPA'], inplace=True)

copied_admission_df.head(10)
# Out:
#                 TOEFL Score  University Rating  SOP  LOR  Research  \
# GRE Score CGPA
# 337       9.65          118                  4  4.5  4.5         1
# 316       8.00          104                  3  3.0  3.5         1
# 322       8.67          110                  3  3.5  2.5         1
# 314       8.21          103                  2  2.0  3.0         0
# 330       9.34          115                  5  4.5  3.0         1
# 321       8.20          109                  3  3.0  4.0         1
# 308       7.90          101                  2  3.0  4.0         0
# 302       8.00          102                  1  2.0  1.5         0
# 323       8.60          108                  3  3.5  3.0         0
# 327       9.00          111                  4  4.0  4.5         1
#
#                 Chance of Admit
# GRE Score CGPA
# 337       9.65             0.92
# 316       8.00             0.72
# 322       8.67             0.80
# 314       8.21             0.65
# 330       9.34             0.90
# 321       8.20             0.75
# 308       7.90             0.68
# 302       8.00             0.50
# 323       8.60             0.45
# 327       9.00             0.84

# %%
# Remove the "GRE Score" and "CGPA" columns
copied_admission_df.drop(columns=['GRE Score', 'CGPA'], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/rg/9mqy0ndj26v32y8v4h0_16h80000gn/T/ipykernel_69161/1420906279.py in <module>
#       1 # Remove the "GRE Score" and "CGPA" columns
# ----> 2 copied_admission_df.drop(columns=['GRE Score', 'CGPA'], inplace=True)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4955                 weight  1.0     0.8
#    4956         """
# -> 4957         return super().drop(
#    4958             labels=labels,
#    4959             axis=axis,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4265         for axis, labels in axes.items():
#    4266             if labels is not None:
# -> 4267                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4268
#    4269         if inplace:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors, consolidate, only_slice)
#    4309                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4310             else:
# -> 4311                 new_axis = axis.drop(labels, errors=errors)
#    4312             indexer = axis.get_indexer(new_axis)
#    4313
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    6659         if mask.any():
#    6660             if errors != "ignore":
# -> 6661                 raise KeyError(f"{list(labels[mask])} not found in axis")
#    6662             indexer = indexer[~mask]
#    6663         return self.delete(indexer)
#
# KeyError: "['GRE Score', 'CGPA'] not found in axis"

# %%
# Change the index back to a sequence starting at zero
copied_admission_df.reset_index(inplace=True)

# %%
copied_admission_df.sample(4)
# Out:
#      GRE Score  CGPA  TOEFL Score  University Rating  SOP  LOR  Research  \
# 47         312  7.90          100                  2  1.5  3.5         1
# 61         325  8.92          112                  4  3.5  3.5         0
# 315        297  7.89           96                  2  2.5  1.5         0
# 145        321  9.06          112                  5  5.0  5.0         1
#
#      Chance of Admit
# 47              0.56
# 61              0.55
# 315             0.43
# 145             0.86

# %% [markdown]
# # Challenge 2 - Advanced Functions
# In this part of the lab, we would like to test complex conditions on the entire dataset at once. Let's start by finding the number of rows where the CGPA is higher than 9 and the student has conducted research.

# %%
admission_df.head()
# Out:
#             GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# Serial No.
# 1                 337          118                  4  4.5  4.5  9.65
# 2                 316          104                  3  3.0  3.5  8.00
# 3                 322          110                  3  3.5  2.5  8.67
# 4                 314          103                  2  2.0  3.0  8.21
# 5                 330          115                  5  4.5  3.0  9.34
#
#             Research  Chance of Admit
# Serial No.
# 1                  1             0.92
# 2                  1             0.72
# 3                  1             0.80
# 4                  0             0.65
# 5                  1             0.90

# %%
# Filter the rows where CGPA > 9 and Research is 1 (indicating conducted research)
filtered_admission_df = admission_df[(admission_df['CGPA'] > 9) & (admission_df['Research'] == 1)]

# Get the number of rows in the filtered DataFrame
num_rows = filtered_admission_df.shape[0]


filtered_admission_df
# Out:
#             GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# Serial No.
# 1                 337          118                  4  4.5  4.5  9.65
# 5                 330          115                  5  4.5  3.0  9.34
# 11                328          112                  4  4.0  4.5  9.10
# 20                328          116                  5  5.0  5.0  9.50
# 21                334          119                  5  5.0  4.5  9.70
# ...               ...          ...                ...  ...  ...   ...
# 380               329          111                  4  4.5  4.0  9.23
# 381               324          110                  3  3.5  3.5  9.04
# 382               325          107                  3  3.0  3.5  9.11
# 383               330          116                  4  5.0  4.5  9.45
# 385               333          117                  4  5.0  4.0  9.66
#
#             Research  Chance of Admit
# Serial No.
# 1                  1             0.92
# 5                  1             0.90
# 11                 1             0.78
# 20                 1             0.94
# 21                 1             0.95
# ...              ...              ...
# 380                1             0.89
# 381                1             0.82
# 382                1             0.84
# 383                1             0.91
# 385                1             0.95
#
# [101 rows x 8 columns]

# %%
print("Number of rows where CGPA > 9 and Research is conducted:", num_rows)
# Out:
# Number of rows where CGPA > 9 and Research is conducted: 101

# %% [markdown]
# #
# We would like to create a deciding factor column for each student. We standardize several columns and then pick the most important factor from a lookup table. If the standardized value is above 0.8, the student will be accepted.
#
# We will start by creating a standardized column for CGPA, GRE Score and LOR. We will name these columns CGPA_std, GRE_std, and LOR_std respecively.
#
# Recall that standardizing a column is done by subtracting the mean of the column from all observations in the column and then dividing each observation in the column by the column's standard deviation.
#
# In the cell below, write a standardization function (a function that takes a column as input and returns a standardized column as output). Make sure to use the numpy versions of mean and standard deviation.

# %%
def standardize_column(column):
    # Calculate the mean and standard deviation of the column using NumPy
    column_mean = np.mean(column)
    column_std = np.std(column)
    
    # Standardize the column by subtracting the mean and dividing by the standard deviation
    standardized_column = (column - column_mean) / column_std
    
    return standardized_column

# %% [markdown]
# #
# Now create the standardized columns CGPA_std, GRE_std, and LOR_std and add them to the admissions dataframe.

# %%
admission_df['CGPA_std'] = standardize_column(admission_df['CGPA'])

# %%
#Repeat this process for the other columns as well:

# %%
admission_df['GRE_std'] = standardize_column(admission_df['GRE Score'])
admission_df['LOR_std'] = standardize_column(admission_df['LOR'])

# %%
admission_df.head(3)
# Out:
#             GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# Serial No.
# 1                 337          118                  4  4.5  4.5  9.65
# 2                 316          104                  3  3.0  3.5  8.00
# 3                 322          110                  3  3.5  2.5  8.67
#
#             Research  Chance of Admit  CGPA_std   GRE_std   LOR_std
# Serial No.
# 1                  1             0.92  1.750174  1.755663  1.193197
# 2                  1             0.72 -0.992501 -0.063450  0.076840
# 3                  1             0.80  0.121191  0.456297 -1.039517

# %% [markdown]
# #
# This will add the standardized columns CGPA_std, GRE_std, and LOR_std to your DataFrame based on the respective input columns.

# %% [markdown]
# #
# We will generate the decision choice at random using the code below. Please run the cell.

# %%
# Libraries
from random import choices

# %%
standardized_columns = ['CGPA_std', 'GRE_std', 'LOR_std']

decision_choice = choices(std_columns, k=admission_df.shape[0])

# %% [markdown]
# #
# Now create the deciding column using the lookup function. The lookup column is decision_choice found above. Call the column resulting from the lookup function deciding_column and add it to the admissions dataframe.

# %%
# Now we have a "Admission" DataFrame and 'decision_choice' as described above

# Defining a function to perform the lookup and return the decision
def lookup_decision(row):
    return decision_choice[decision_choice['standardized_columns'] == row]['Decision'].values[0]

# %%
# Create the deciding column in the "Admission" DataFrame using the lookup function
admission_df['deciding_column'] = admission_df['standardized_columns'].apply(lookup_decision)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'standardized_columns'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /var/folders/rg/9mqy0ndj26v32y8v4h0_16h80000gn/T/ipykernel_69161/3283106708.py in <module>
#       1 # Create the deciding column in the "Admission" DataFrame using the lookup function
# ----> 2 admission_df['deciding_column'] = admission_df['standardized_columns'].apply(lookup_decision)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3503             if self.columns.nlevels > 1:
#    3504                 return self._getitem_multilevel(key)
# -> 3505             indexer = self.columns.get_loc(key)
#    3506             if is_integer(indexer):
#    3507                 indexer = [indexer]
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
# -> 3631                 raise KeyError(key) from err
#    3632             except TypeError:
#    3633                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'standardized_columns'

# %%
admission_df.head(3)
# Out:
#             GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# Serial No.
# 1                 337          118                  4  4.5  4.5  9.65
# 2                 316          104                  3  3.0  3.5  8.00
# 3                 322          110                  3  3.5  2.5  8.67
#
#             Research  Chance of Admit  CGPA_std   GRE_std   LOR_std
# Serial No.
# 1                  1             0.92  1.750174  1.755663  1.193197
# 2                  1             0.72 -0.992501 -0.063450  0.076840
# 3                  1             0.80  0.121191  0.456297 -1.039517

# %% [markdown]
# #
# Create a column called decision in the admissions dataframe. Assign 1 to this column if the value of deciding_column is greater than 0.8 and 0 otherwise

# %%
# Defining a function to create the "decision" column
def make_decision(row):
    if row['deciding_column'] > 0.8:
        return 1
    else:
        return 0

# Apply the function to create the "decision" column
admission_df['decision'] = admission_df.apply(make_decision, axis=1)

# Display the resulting DataFrame
print(admissions)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'deciding_column'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /var/folders/rg/9mqy0ndj26v32y8v4h0_16h80000gn/T/ipykernel_69161/4146838213.py in <module>
#       7
#       8 # Apply the function to create the "decision" column
# ----> 9 admission_df['decision'] = admission_df.apply(make_decision, axis=1)
#      10
#      11 # Display the resulting DataFrame
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwargs)
#    8846             kwargs=kwargs,
#    8847         )
# -> 8848         return op.apply().__finalize__(self, method="apply")
#    8849
#    8850     def applymap(
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/apply.py in apply(self)
#     731             return self.apply_raw()
#     732
# --> 733         return self.apply_standard()
#     734
#     735     def agg(self):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/apply.py in apply_standard(self)
#     855
#     856     def apply_standard(self):
# --> 857         results, res_index = self.apply_series_generator()
#     858
#     859         # wrap results
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/apply.py in apply_series_generator(self)
#     871             for i, v in enumerate(series_gen):
#     872                 # ignore SettingWithCopy here in case the user mutates
# --> 873                 results[i] = self.f(v)
#     874                 if isinstance(results[i], ABCSeries):
#     875                     # If we have a view on v, we need to make a copy because
#
# /var/folders/rg/9mqy0ndj26v32y8v4h0_16h80000gn/T/ipykernel_69161/4146838213.py in make_decision(row)
#       1 # Defining a function to create the "decision" column
#       2 def make_decision(row):
# ----> 3     if row['deciding_column'] > 0.8:
#       4         return 1
#       5     else:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/series.py in __getitem__(self, key)
#     956
#     957         elif key_is_scalar:
# --> 958             return self._get_value(key)
#     959
#     960         if is_hashable(key):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/series.py in _get_value(self, label, takeable)
#    1067
#    1068         # Similar to Index.get_value, but we do not fall back to positional
# -> 1069         loc = self.index.get_loc(label)
#    1070         return self.index._get_values_for_loc(self, loc, label)
#    1071
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
# -> 3631                 raise KeyError(key) from err
#    3632             except TypeError:
#    3633                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'deciding_column'

# %% [markdown]
# #
# How many applicants will be accepted to the program using the decision column? Compute the result below

# %%
# Count the number of accepted applicants
accepted_count = admission_df['decision'].sum()

print("Number of applicants accepted to the program:", accepted_count)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'decision'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /var/folders/rg/9mqy0ndj26v32y8v4h0_16h80000gn/T/ipykernel_69161/740255267.py in <module>
#       1 # Count the number of accepted applicants
# ----> 2 accepted_count = admission_df['decision'].sum()
#       3
#       4 print("Number of applicants accepted to the program:", accepted_count)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3503             if self.columns.nlevels > 1:
#    3504                 return self._getitem_multilevel(key)
# -> 3505             indexer = self.columns.get_loc(key)
#    3506             if is_integer(indexer):
#    3507                 indexer = [indexer]
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
# -> 3631                 raise KeyError(key) from err
#    3632             except TypeError:
#    3633                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'decision'

# %%
#Note for TA's : For the last 3 questions, key error exists. I tried to solve it but error still exists. 
#Please check and let me know where the things are going wrong.

# %% [markdown]
# # Challenge 3 - Method Chaining
# To increase our coding efficiency, let's make a number of changes to our dataframe in one line of code.
#
# In the cell below, remove all non character symbols from the column names, replace all spaces in column names to underscores, and change all upper case characters to lower case. Assign these new column values to admissions.columns.

# %% [markdown]
# #
# In the cell below, give all student with a university rating of 4 or higher a 10 point boost on their GRE score and split the column into 4 bins using the cut function. Assign this new score to the variable adjusted_gre.
